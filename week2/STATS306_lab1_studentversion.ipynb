# %% [markdown]
# # Lab 1: Exercises in ggplot

# %% [markdown]
# ## Playing around with ggplot

# %%
suppressMessages(require(tidyverse))
options(repr.plot.width=4, repr.plot.height=3)

# %% [markdown]
# ### Lets look at the diamonds dataset, which contains diamond color, price, weight, and etc. We first call the head function to see the first few rows of the dataset.

# %%
head(diamonds)
# Out:
#   carat cut       color clarity depth table price x    y    z
# 1 0.23  Ideal     E     SI2     61.5  55    326   3.95 3.98 2.43
# 2 0.21  Premium   E     SI1     59.8  61    326   3.89 3.84 2.31
# 3 0.23  Good      E     VS1     56.9  65    327   4.05 4.07 2.31
# 4 0.29  Premium   I     VS2     62.4  58    334   4.20 4.23 2.63
# 5 0.31  Good      J     SI2     63.3  58    335   4.34 4.35 2.75
# 6 0.24  Very Good J     VVS2    62.8  57    336   3.94 3.96 2.48

# %% [markdown]
# ### A run down on diamonds by [Tiffany & Co](https://www.tiffany.com/engagement/the-tiffany-guide-to-diamonds) is helpful :P

# %%
summary(diamonds)
# Out:
#      carat               cut        color        clarity          depth
#  Min.   :0.2000   Fair     : 1610   D: 6775   SI1    :13065   Min.   :43.00
#  1st Qu.:0.4000   Good     : 4906   E: 9797   VS2    :12258   1st Qu.:61.00
#  Median :0.7000   Very Good:12082   F: 9542   SI2    : 9194   Median :61.80
#  Mean   :0.7979   Premium  :13791   G:11292   VS1    : 8171   Mean   :61.75
#  3rd Qu.:1.0400   Ideal    :21551   H: 8304   VVS2   : 5066   3rd Qu.:62.50
#  Max.   :5.0100                     I: 5422   VVS1   : 3655   Max.   :79.00
#                                     J: 2808   (Other): 2531
#      table           price             x                y
#  Min.   :43.00   Min.   :  326   Min.   : 0.000   Min.   : 0.000
#  1st Qu.:56.00   1st Qu.:  950   1st Qu.: 4.710   1st Qu.: 4.720
#  Median :57.00   Median : 2401   Median : 5.700   Median : 5.710
#  Mean   :57.46   Mean   : 3933   Mean   : 5.731   Mean   : 5.735
#  3rd Qu.:59.00   3rd Qu.: 5324   3rd Qu.: 6.540   3rd Qu.: 6.540
# ...

# %% [markdown]
# ##  Questions for thought:
# 1. For diamonds of various sizes, which size is the most overpriced by Tiffany according to our price table?
# 2. If you have a budget of $12,000, which diamond in our dataset would you buy?

# %% [markdown]
# # Creating the first plot
# ### Ex1: plot carat on the x-axis and price on the y-axis. (Hint: use geom_point())

# %%
ggplot(data=diamonds) + 
    geom_point()
# Out:
# plot without title

# %% [markdown]
# ### Ex2: On the same plot, add the following x label, y label, and title.

# %%
ggplot(data=diamonds) + 
    geom_point() +
    labs() +
    ggtitle()
# Out:
# plot without title

# %% [markdown]
# ### Ex3: On the last plot, color the points by clarity
# ### Optional: how to change color wheel?

# %%
ggplot(data = diamonds) + 
    geom_point() +
    labs() + 
    ggtitle()
# Out:
# plot without title

# %% [markdown]
# ### Ex4: On the last plot, color all points blue.

# %%
ggplot(data = diamonds) + 
    geom_point() +
    labs() + 
    ggtitle()
# Out:
# plot without title

# %% [markdown]
# ### Ex5: plot diamond count against diamond color in bar plot. show diamond cut by plot color. Hint: geom_bar()
# ### Optional: What if we want one bar for each cut, rather than stacking them up horizontally?

# %%
ggplot(data = diamonds) +
# Out:
# plot without title

# %% [markdown]
# ### Ex6: create the following boxplot to help visualize the variability of the price for each cut

# %%
# boxplot helps to visualize the variability of a price for each cut
ggplot(data = diamonds) +
# Out:
# plot without title

# %% [markdown]
# ### Ex7: Generate 5 plots of price vs width, with one for each cut type. Hint: use facet_wrap()..

# %%
ggplot(data = diamonds) + 
    geom_point(mapping = aes(x = x, y = price)) +
    labs(x = 'Width', y = 'Price($)') + 
    ggtitle('Diamond price by Width')
# Out:
# plot without title

# %% [markdown]
# ### Ex8:  Generate plots of price vs width, with one plot for each (color, cut) combination. Hint: what other facet function can be used?

# %%
ggplot(data = diamonds) + 
    geom_point(mapping = aes(x = x, y = price)) +
    labs(x = 'Width', y = 'Price($)') + 
    ggtitle('Diamond price by Width')
# Out:
# plot without title
